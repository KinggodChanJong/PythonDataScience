# %% [markdown]
# # 게임 점유율 순위
#
# ### TOP12 게임 점유율 분석
#
# ### 출처 : http://www.gametrics.com/

# %%
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt
# %matplotlib inline

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
game_rating = pd.read_excel('../data/rating_game.xlsx', encoding ='utf-8')
game_rating
# Out:
#     Unnamed: 0      1월      2월      3월      4월      5월      6월      7월  \
# 0      리그오브레전드  0.3085  0.3344  0.3490  0.3603  0.3948  0.3966  0.4277
# 1       배틀그라운드  0.1826  0.1819  0.1772  0.1701  0.1498  0.1305  0.1156
# 2       피파온라인4  0.0751  0.0609  0.0558  0.0544  0.0694  0.0794  0.0817
# 3         오버워치  0.0853  0.0795  0.0809  0.0745  0.0830  0.0779  0.0841
# 4         서든어택  0.0415  0.0419  0.0385  0.0337  0.0327  0.0306  0.0262
# 5       메이플스토리  0.0332  0.0285  0.0195  0.0185  0.0220  0.0350  0.0478
# 6       스타크래프트  0.0265  0.0261  0.0273  0.0290  0.0254  0.0259  0.0230
# 7   월드오브 워크래프트  0.0072  0.0075  0.0081  0.0080  0.0066  0.0059  0.0057
# 8       던전앤파이터  0.0169  0.0172  0.0198  0.0203  0.0175  0.0180  0.0171
# 9        카트라이더  0.0321  0.0450  0.0387  0.0343  0.0324  0.0217  0.0167
# 10       로스트아크  0.0675  0.0497  0.0381  0.0328  0.0249  0.0188  0.0132
# 11         리니지  0.0064  0.0053  0.0081  0.0212  0.0125  0.0097  0.0101
#
#         8월      9월     10월
# ...

# %%
game_rating.set_index('Unnamed: 0',inplace=True)
game_rating
# Out:
#                 1월      2월      3월      4월      5월      6월      7월      8월  \
# Unnamed: 0
# 리그오브레전드     0.3085  0.3344  0.3490  0.3603  0.3948  0.3966  0.4277  0.4199
# 배틀그라운드      0.1826  0.1819  0.1772  0.1701  0.1498  0.1305  0.1156  0.1175
# 피파온라인4      0.0751  0.0609  0.0558  0.0544  0.0694  0.0794  0.0817  0.0825
# 오버워치        0.0853  0.0795  0.0809  0.0745  0.0830  0.0779  0.0841  0.0914
# 서든어택        0.0415  0.0419  0.0385  0.0337  0.0327  0.0306  0.0262  0.0315
# 메이플스토리      0.0332  0.0285  0.0195  0.0185  0.0220  0.0350  0.0478  0.0374
# 스타크래프트      0.0265  0.0261  0.0273  0.0290  0.0254  0.0259  0.0230  0.0241
# 월드오브 워크래프트  0.0072  0.0075  0.0081  0.0080  0.0066  0.0059  0.0057  0.0076
# 던전앤파이터      0.0169  0.0172  0.0198  0.0203  0.0175  0.0180  0.0171  0.0184
# 카트라이더       0.0321  0.0450  0.0387  0.0343  0.0324  0.0217  0.0167  0.0144
# 로스트아크       0.0675  0.0497  0.0381  0.0328  0.0249  0.0188  0.0132  0.0178
# ...

# %%
game_rating.index
# Out:
# Index(['리그오브레전드', '배틀그라운드', '피파온라인4', '오버워치', '서든어택', '메이플스토리', '스타크래프트',
#        '월드오브 워크래프트', '던전앤파이터', '카트라이더', '로스트아크', '리니지'],
#       dtype='object', name='Unnamed: 0')

# %%
game_rating.index.names=['게임명']
game_rating
# Out:
#                 1월      2월      3월      4월      5월      6월      7월      8월  \
# 게임명
# 리그오브레전드     0.3085  0.3344  0.3490  0.3603  0.3948  0.3966  0.4277  0.4199
# 배틀그라운드      0.1826  0.1819  0.1772  0.1701  0.1498  0.1305  0.1156  0.1175
# 피파온라인4      0.0751  0.0609  0.0558  0.0544  0.0694  0.0794  0.0817  0.0825
# 오버워치        0.0853  0.0795  0.0809  0.0745  0.0830  0.0779  0.0841  0.0914
# 서든어택        0.0415  0.0419  0.0385  0.0337  0.0327  0.0306  0.0262  0.0315
# 메이플스토리      0.0332  0.0285  0.0195  0.0185  0.0220  0.0350  0.0478  0.0374
# 스타크래프트      0.0265  0.0261  0.0273  0.0290  0.0254  0.0259  0.0230  0.0241
# 월드오브 워크래프트  0.0072  0.0075  0.0081  0.0080  0.0066  0.0059  0.0057  0.0076
# 던전앤파이터      0.0169  0.0172  0.0198  0.0203  0.0175  0.0180  0.0171  0.0184
# 카트라이더       0.0321  0.0450  0.0387  0.0343  0.0324  0.0217  0.0167  0.0144
# 로스트아크       0.0675  0.0497  0.0381  0.0328  0.0249  0.0188  0.0132  0.0178
# ...

# %%
game_rating.index
# Out:
# Index(['리그오브레전드', '배틀그라운드', '피파온라인4', '오버워치', '서든어택', '메이플스토리', '스타크래프트',
#        '월드오브 워크래프트', '던전앤파이터', '카트라이더', '로스트아크', '리니지'],
#       dtype='object', name='게임명')

# %%
game_rating=game_rating.drop(['리니지','로스트아크'],0)
game_rating
# Out:
#                 1월      2월      3월      4월      5월      6월      7월      8월  \
# 게임명
# 리그오브레전드     0.3085  0.3344  0.3490  0.3603  0.3948  0.3966  0.4277  0.4199
# 배틀그라운드      0.1826  0.1819  0.1772  0.1701  0.1498  0.1305  0.1156  0.1175
# 피파온라인4      0.0751  0.0609  0.0558  0.0544  0.0694  0.0794  0.0817  0.0825
# 오버워치        0.0853  0.0795  0.0809  0.0745  0.0830  0.0779  0.0841  0.0914
# 서든어택        0.0415  0.0419  0.0385  0.0337  0.0327  0.0306  0.0262  0.0315
# 메이플스토리      0.0332  0.0285  0.0195  0.0185  0.0220  0.0350  0.0478  0.0374
# 스타크래프트      0.0265  0.0261  0.0273  0.0290  0.0254  0.0259  0.0230  0.0241
# 월드오브 워크래프트  0.0072  0.0075  0.0081  0.0080  0.0066  0.0059  0.0057  0.0076
# 던전앤파이터      0.0169  0.0172  0.0198  0.0203  0.0175  0.0180  0.0171  0.0184
# 카트라이더       0.0321  0.0450  0.0387  0.0343  0.0324  0.0217  0.0167  0.0144
#
#                 9월     10월
# 게임명
# 리그오브레전드     0.4368  0.4728
# 배틀그라운드      0.1125  0.0985
# 피파온라인4      0.0753  0.0793
# ...

# %%
plt.figure(figsize=(10,6))
for num in range(0,9):
    asdff = np.array(game_rating.loc[game_rating.index[num]])
    plt.plot(game_rating.columns, asdff, label=game_rating.index[num])
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
for num in range(4,7):
    asdff = np.array(game_rating.loc[game_rating.index[num]])
    plt.plot(game_rating.columns, asdff, label=game_rating.index[num])
plt.grid()
plt.legend()
plt.show()
